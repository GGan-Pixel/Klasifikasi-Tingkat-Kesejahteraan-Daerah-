# %%
import pandas as pd 
import streamlit as st
import numpy as np 



# membaca dataset
df = pd.read_csv('statistika.csv')

st.title("Klasifikasi Tingkat Kesejahteraan Masyarakat")

#pengecekan dataset
print(df.head(10))
print(df.info())
print(df.describe())

#visualisasi data sebagai bar chart
df = pd.read_csv("statistika.csv")
data_count = df['Tingkat_Kesejahteraan'].value_counts()
st.bar_chart(data_count)
# Out:
# 2026-04-27 13:05:43.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 13:05:43.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 13:05:43.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 13:05:43.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 13:05:43.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 13:05:43.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#               Provinsi Kabupaten_Kota  Jumlah_Penduduk  Rata_Lama_Sekolah  \
# 0  Nusa Tenggara Barat        Mataram          1453556               10.0
# 1          DKI Jakarta  Jakarta Utara          1275850               10.7
# ...
